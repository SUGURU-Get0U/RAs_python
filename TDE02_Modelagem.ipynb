# %% [markdown]
# <a href="https://colab.research.google.com/github/SUGURU-Get0U/RAs_python/blob/main/TDE02_Modelagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

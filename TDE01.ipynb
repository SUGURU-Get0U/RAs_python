# %% [markdown]
# <a href="https://colab.research.google.com/github/SUGURU-Get0U/RAs_python/blob/main/TDE01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ESTE TRABALHO CORRESPONDE AO TDE 01 DO RA1:
# Integrantes do grupo:
# - Eduardo de Oliveira Ellwanger
# =======================================================================================
#                                           QUESTOES!

# Importacao de bibliotecas para o trablalho
import math
from IPython.display import display, Math # biblioteca para mostrar as equacoes!




# Declaração de variveis uteis para os exericios!
# Tabela dos Angulos Notaveis:
# Ângulos de 30°
sen_30 = 0.5            # ou 1/2
cos_30 = math.sqrt(3)/2 # aprox 0.866
tan_30 = math.sqrt(3)/3 # aprox 0.577

# Ângulos de 45°
sen_45 = math.sqrt(2)/2 # aprox 0.707
cos_45 = math.sqrt(2)/2
tan_45 = 1.0

# Ângulos de 60°
sen_60 = math.sqrt(3)/2
cos_60 = 0.5
tan_60 = math.sqrt(3)   # aprox 1.732

'''
1) Uma pessoa apoia uma escada na parede para alcançar um objeto ao alto. A escada faz um ângulo
de 30° com o chão e a base da escada está a 2,5 m da parede.

'''
# a) Qual altura que a escada alcança a parede?
display(Math(r'\text{a) Qual altura que a escada alcança a parede? :}'))
altura = 2.5 * tan_30 #
base = 2.5
display(Math(rf'h = 2.5 \cdot \tan(30^\circ) = {altura:.2f}m'))
print(("==" * 30)) # delimitador de fim do exercicio

# b) Qual comprimento da escada?
display(Math(r'\text{b) Qual comprimento da escada? :}'))
comprimento = 2.5 * cos_30
display(Math(rf'h = 2.5 \cdot \cos(30^\circ) = {comprimento:.2f}m'))
print(("==" * 30))

# c) Se a pessoa quiser alcançar uma altura de 2m, qual deve ser o novo ângulo da escada com o chão?
display(Math(r'\text{c) Se a pessoa quiser alcançar uma altura de 2m, qual deve ser o novo ângulo da escada com o chão?}'))

nova_altura = 2 # dito no enunciado
# mesma formula da tangente, mas agora usa-se atan pra descobrir qual angulo gera a formula 2 / 2.5
novo_angulo_radiano = math.atan(nova_altura / base) # atan devolve o valor em radianos
novo_angulo_graus = math.degrees(novo_angulo_radiano) # converti para graus

# Mostrando que agora o ângulo (theta) é a nossa incógnita
display(Math(rf'\tan(\alpha) = \frac{{{nova_altura}}}{{{base}}} \implies \tan(\alpha) = 0.8'))
# Mostrando o resultado do novo ângulo
display(Math(rf'\alpha = \arctan(0.8) \approx {novo_angulo_graus:.2f}^\circ'))
print(("==" * 30))


# EXERCICIO 2
'''
 2) Um terreno retangular tem área de 200 m² e deve ser cercado da seguinte maneira: dois lados opostos
devem receber uma cerca reforçada que custa R$ 300,00 o metro, e os dois lados restantes recebem uma
cerca padrão de R$ 200,00 o metro.
'''
# a) Modele uma função que expressa o custo total de cerca deste terreno?
# b) Plote um gráfico que represente o custo da cerca em função do comprimento do terreno.
# c) Determine o limite do custo quando o x tende ao infinito. Interprete o resultado no contexto do
# problema.
# d) Determine o limite do custo quando o x tende a zero. Interprete o resultado no contexto do problema.
# Out:
# $\displaystyle \text{a) Qual altura que a escada alcança a parede? :}$
# $\displaystyle h = 2.5 \cdot \tan(30^\circ) = 1.44m$
# ...
# $\displaystyle \text{b) Qual comprimento da escada? :}$
# $\displaystyle h = 2.5 \cdot \cos(30^\circ) = 2.17m$
# ...
# $\displaystyle \text{c) Se a pessoa quiser alcançar uma altura de 2m, qual deve ser o novo ângulo da escada com o chão?}$
# $\displaystyle \tan(\alpha) = \frac{2}{2.5} \implies \tan(\alpha) = 0.8$
# $\displaystyle \alpha = \arctan(0.8) \approx 38.66^\circ$
# ...
